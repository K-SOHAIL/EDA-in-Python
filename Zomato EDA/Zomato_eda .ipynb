# %%
print ("Hello world")
# Out:
# Hello world

# %% [markdown]
# ### EDA on Zomato Data sed

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
Zomato_Data = pd.read_csv('zomato.csv',encoding='latin-1')
Zomato_Data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
Zomato_Data.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730              NamlÛ± Gurme           208  ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208  ÛÁstanbul
# 9548        5915807                     Huqqa           208  ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208  ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address     Locality  \
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...     Karakí_y
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...    Koôuyolu
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karakí_y, ÛÁstanbul  28.977392  41.022793
# ...

# %%
Zomato_Data.sum()
# Out:
# Restaurant ID                                                 86447326863
# Restaurant Name         Le Petit SouffleIzakaya KikufujiHeat - Edsa Sh...
# Country Code                                                       175410
# City                    Makati CityMakati CityMandaluyong CityMandaluy...
# Address                 Third Floor, Century City Mall, Kalayaan Avenu...
# Locality                Century City Mall, Poblacion, Makati CityLittl...
# Locality Verbose        Century City Mall, Poblacion, Makati City, Mak...
# Longitude                                                          612473
# Latitude                                                           246935
# Average Cost for two                                             11453662
# Currency                Botswana Pula(P)Botswana Pula(P)Botswana Pula(...
# Has Table booking       YesYesYesNoYesNoYesYesYesYesNoYesNoYesNoNoNoYe...
# Has Online delivery     NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# ...

# %%
Zomato_Data.min()
# Out:
# Restaurant ID                                                          53
# Restaurant Name                                              Let's Burrrp
# Country Code                                                            1
# City                                                            Abu Dhabi
# Address                 1 & 2, Block A-5 B, DDA Market, Paschim Vihar,...
# Locality                                ILD Trade Centre Mall, Sohna Road
# Locality Verbose               ILD Trade Centre Mall, Sohna Road, Gurgaon
# Longitude                                                        -157.948
# Latitude                                                         -41.3304
# Average Cost for two                                                    0
# Currency                                                 Botswana Pula(P)
# Has Table booking                                                      No
# Has Online delivery                                                    No
# ...

# %%
Zomato_Data.max()
# Out:
# Restaurant ID                                                    18500652
# Restaurant Name                                       íukuraÛôa SofrasÛ±
# Country Code                                                          216
# City                                                            ÛÁstanbul
# Address                 íìmitkí_y Mahallesi, 2432. Cadde (8. Cadde), N...
# Locality                                                        íìmitkí_y
# Locality Verbose                                        íìmitkí_y, Ankara
# Longitude                                                         174.832
# Latitude                                                           55.977
# Average Cost for two                                               800000
# Currency                                                 Turkish Lira(TL)
# Has Table booking                                                     Yes
# Has Online delivery                                                   Yes
# ...

# %%
Zomato_Data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
Zomato_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
# Restaurant ID           9551 non-null int64
# Restaurant Name         9551 non-null object
# Country Code            9551 non-null int64
# City                    9551 non-null object
# Address                 9551 non-null object
# Locality                9551 non-null object
# Locality Verbose        9551 non-null object
# Longitude               9551 non-null float64
# Latitude                9551 non-null float64
# Cuisines                9542 non-null object
# Average Cost for two    9551 non-null int64
# Currency                9551 non-null object
# Has Table booking       9551 non-null object
# Has Online delivery     9551 non-null object
# Is delivering now       9551 non-null object
# Switch to order menu    9551 non-null object
# Price range             9551 non-null int64
# Aggregate rating        9551 non-null float64
# ...

# %%
Zomato_Data.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
pip install pandas_profiling
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/45/83/6dc308c763d00c6d3ee66c4dcf06b2d020bc774326ee03bf23076a5f25ce/pandas_profiling-3.6.2-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/62/fa/6a8539c83d2ccbd08d5f0c843b1784af9ff514e77f4c9d5d6800fdd340f6/visions-0.7.5-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/8f/2e/17bbb83fbf102687bb2aa3d808add39da820a7698159302a1a69bb82e01c/seaborn-0.12.2-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/40/69/4af412d078cef2298f7d90546fa0e03e65a032558bd85319239c72ae0c3c/scipy-1.7.3-cp37-cp37m-win_amd64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/b7/b3/e327612b67b2ab93749e648a92e5463cba763e7d4e8c74f69551133df076/phik-0.12.3-cp37-cp37m-win_amd64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/bc/c3/f068337a370801f372f2f8f6bad74a5c140f6fda3d9de154052708dd3c65/Jinja2-3.1.2-py3-none-any.whl
# ...

# %%
import pandas_profiling
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6a00893fb3e1> in <module>
# ----> 1 import pandas_profiling
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %% [markdown]
# ## In Data Analysis What All Things We Do
# 1. Missing Values
# 2. Explore About the Numerical Variables
# 3. Explore About categorical Variables
# 4. Findings Relationship between features

# %%
Zomato_NAN = Zomato_Data

# %%
Zomato_NAN.shape
# Out:
# (9551, 21)

# %%
Zomato_NAN.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
[features for features in Zomato_NAN .columns if Zomato_NAN [features].isnull().sum()>1]
# Out:
# ['Cuisines']

# %%
sns.heatmap(Zomato_NAN.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
Zomato_country=pd.read_excel('Country-Code.xlsx')
Zomato_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
Zomato_NAN.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
final_Zomato=pd.merge(Zomato_NAN,Zomato_country,on='Country Code',how='left')

# %%
final_Zomato.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
# 1                    Japanese  ...                Yes                  No
#
# ...

# %%
## To check data types
final_Zomato.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
final_Zomato.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_Zomato.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# UAE                 60
# Brazil              60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Sri Lanka           20
# Qatar               20
# Canada               4
# Name: Country, dtype: int64

# %%
final_Zomato.Country.value_counts().index
# Out:
# Index(['India', 'United States', 'United Kingdom', 'UAE', 'Brazil',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Sri Lanka', 'Qatar', 'Canada'],
#       dtype='object')

# %%
country_names=final_Zomato.Country.value_counts().index

# %%
final_Zomato.Country.value_counts().values
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4], dtype=int64)

# %%
country_val=final_Zomato.Country.value_counts().values

# %%
### pie chart 
plt.pie(country_val,labels=country_names)
# Out:
# ([<matplotlib.patches.Wedge at 0x228bcb72e80>,
# ...
#  [Text(-1.052256163793291, 0.3205572737577906, 'India'),
#   Text(0.9911329812843455, -0.477132490415823, 'United States'),
#   Text(1.0572858296119743, -0.3035567072257165, 'United Kingdom'),
#   Text(1.070138816916019, -0.2545641619112621, 'UAE'),
#   Text(1.0793506814479759, -0.21213699926648824, 'Brazil'),
#   Text(1.086881147244973, -0.16937937230799818, 'South Africa'),
#   Text(1.0918635911832035, -0.1335436192729486, 'New Zealand'),
#   Text(1.0947903814016446, -0.10692998078388304, 'Turkey'),
#   Text(1.096631023945382, -0.08602556201794338, 'Australia'),
#   Text(1.0978070729776455, -0.06942355882735218, 'Phillipines'),
#   Text(1.0986791544015209, -0.05388984768543213, 'Indonesia'),
#   Text(1.0993059848742366, -0.039068550263413035, 'Singapore'),
#   Text(1.0997248508282123, -0.02460187941736628, 'Sri Lanka'),
#   Text(1.0999533462179636, -0.010130949802716446, 'Qatar'),
# ...

# %%
### pie chart- top 3 countries that uses zomato
plt.pie(country_val[:3],labels=country_names[:3])
# Out:
# ([<matplotlib.patches.Wedge at 0x228bca8c320>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')])

# %%
### pie chart- top 3 countries that uses zomato(percantage)
plt.pie(country_val[:3],labels=country_names[:3],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x228bcac6198>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.39%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.73%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.87%')])

# %%
### pie chart- top 3 countries that uses zomato(percantage)
plt.pie(country_val[:3],labels=country_names[:3],autopct='%1.f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x228bcafe4e0>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94%'),
#   Text(0.5876082086391032, -0.12131196618612707, '5%'),
#   Text(0.5997744629358018, -0.01644972978715676, '1%')])

# %% [markdown]
# Observation : Zomato maximum transaction are from India after that USA and
#     then United Kingdoms

# %%
final_Zomato.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_Zomato.groupby(['Aggregate rating','Rating color','Rating text'])

# %%
final_Zomato.groupby(['Aggregate rating','Rating color','Rating text']).size().head()
# Out:
# Aggregate rating  Rating color  Rating text
# 0.0               White         Not rated      2148
# 1.8               Red           Poor              1
# 1.9               Red           Poor              2
# 2.0               Red           Poor              7
# 2.1               Red           Poor             15
# dtype: int64

# %%
final_Zomato.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().head()
# Out:
#    Aggregate rating Rating color Rating text     0
# 0               0.0        White   Not rated  2148
# 1               1.8          Red        Poor     1
# 2               1.9          Red        Poor     2
# 3               2.0          Red        Poor     7
# 4               2.1          Red        Poor    15

# %%
final_Zomato.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'rating count'})
# Out:
#     Aggregate rating Rating color Rating text  rating count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
Ratings_Zomato =final_Zomato.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'rating count'})

# %%
Ratings_Zomato
# Out:
#     Aggregate rating Rating color Rating text  rating count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# ## Observation
# 1. when ratings is between 4.5 to 4.9---> excellent
# 2. when rating is between 4.0 to 4.4 ----> very good
# 3. when rating is between 3.5 to 3.9----> good
# 4. when ratings is between 2.5 to 3.4---> average
# 5. when ratings is between 1.8 to 2.4---> poor

# %%
Ratings_Zomato.head()
# Out:
#    Aggregate rating Rating color Rating text  rating count
# 0               0.0        White   Not rated          2148
# 1               1.8          Red        Poor             1
# 2               1.9          Red        Poor             2
# 3               2.0          Red        Poor             7
# 4               2.1          Red        Poor            15

# %%
sns.barplot(x="Aggregate rating",y="rating count",data=Ratings_Zomato)

# %%
sns.barplot(x="Aggregate rating",y="rating count",data=Ratings_Zomato[14:])

# %%
## import matplotlib
## matplotlib.rcParams['figure.figsize'] = (12,6)
plt.rcParams['figure.figsize'] = (12,6)
sns.barplot(x="Aggregate rating",y="rating count",data=Ratings_Zomato)

# %%
## import matplotlib
## matplotlib.rcParams['figure.figsize'] = (12,6)
plt.rcParams['figure.figsize'] = (12,6)
sns.barplot(x="Aggregate rating",y="rating count",data=Ratings_Zomato[5:])

# %%
##plt.rcParams['figure.figsize'] = (12,6)
sns.barplot(x="Aggregate rating",y="rating count",hue="Rating color",data=Ratings_Zomato)

# %%
sns.barplot(x="Aggregate rating",y="rating count",hue="Rating color",data=Ratings_Zomato,palette=['blue','red','orange','yellow','green','green'])

# %% [markdown]
# ## Observation
# 1. Not rated count is very high
# 2. Maximum number of rating are between 2.5 to 3.5

# %%
## count plot 
sns.countplot(x="Rating color",data=Ratings_Zomato,palette=['blue','red','orange','yellow','green','green']).set_title('Ratings Count by Colour')
# Out:
# Text(0.5, 1.0, 'Ratings Count by Colour')

# %%
## find the countries name that has given rating
final_Zomato.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
Ratings_Zomato.columns
# Out:
# Index(['Aggregate rating', 'Rating color', 'Rating text', 'rating count'], dtype='object')

# %%
final_Zomato[final_Zomato['Rating color']=='White'].groupby(['Aggregate rating','Country']).size().reset_index()
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3

# %% [markdown]
# Observations
# maximum number of 0 ratings are from Indian customers

# %%
## find out Which currency is used by ehich country
final_Zomato.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_Zomato[['Country','Currency']]
# Out:
#           Country            Currency
# 0     Phillipines    Botswana Pula(P)
# 1     Phillipines    Botswana Pula(P)
# 2     Phillipines    Botswana Pula(P)
# 3     Phillipines    Botswana Pula(P)
# 4     Phillipines    Botswana Pula(P)
# 5     Phillipines    Botswana Pula(P)
# 6     Phillipines    Botswana Pula(P)
# 7     Phillipines    Botswana Pula(P)
# 8     Phillipines    Botswana Pula(P)
# 9     Phillipines    Botswana Pula(P)
# 10    Phillipines    Botswana Pula(P)
# 11    Phillipines    Botswana Pula(P)
# 12    Phillipines    Botswana Pula(P)
# 13    Phillipines    Botswana Pula(P)
# 14    Phillipines    Botswana Pula(P)
# 15    Phillipines    Botswana Pula(P)
# 16    Phillipines    Botswana Pula(P)
# 17    Phillipines    Botswana Pula(P)
# 18    Phillipines    Botswana Pula(P)
# 19    Phillipines    Botswana Pula(P)
# 20    Phillipines    Botswana Pula(P)
# 21    Phillipines    Botswana Pula(P)
# 22         Brazil  Brazilian Real(R$)
# 23         Brazil  Brazilian Real(R$)
# ...

# %%
final_Zomato[['Country','Currency']].groupby(['Country','Currency'])

# %%
final_Zomato[['Country','Currency']].groupby(['Country','Currency']).size()
# Out:
# Country         Currency
# Australia       Dollar($)                   24
# Brazil          Brazilian Real(R$)          60
# Canada          Dollar($)                    4
# India           Indian Rupees(Rs.)        8652
# Indonesia       Indonesian Rupiah(IDR)      21
# New Zealand     NewZealand($)               40
# Phillipines     Botswana Pula(P)            22
# Qatar           Qatari Rial(QR)             20
# Singapore       Dollar($)                   20
# South Africa    Rand(R)                     60
# Sri Lanka       Sri Lankan Rupee(LKR)       20
# Turkey          Turkish Lira(TL)            34
# UAE             Emirati Diram(AED)          60
# United Kingdom  Pounds(£)                  80
# United States   Dollar($)                  434
# dtype: int64

# %%
final_Zomato[['Country','Currency']].groupby(['Country','Currency']).size().reset_index()
# Out:
#            Country                Currency     0
# 0        Australia               Dollar($)    24
# 1           Brazil      Brazilian Real(R$)    60
# 2           Canada               Dollar($)     4
# 3            India      Indian Rupees(Rs.)  8652
# 4        Indonesia  Indonesian Rupiah(IDR)    21
# 5      New Zealand           NewZealand($)    40
# 6      Phillipines        Botswana Pula(P)    22
# 7            Qatar         Qatari Rial(QR)    20
# 8        Singapore               Dollar($)    20
# 9     South Africa                 Rand(R)    60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)    20
# 11          Turkey        Turkish Lira(TL)    34
# 12             UAE      Emirati Diram(AED)    60
# 13  United Kingdom              Pounds(£)    80
# 14   United States               Dollar($)   434

# %%
final_Zomato[['Country','Currency']].groupby(['Country','Currency']).size().reset_index().rename(columns={0:'Currency count'})
# Out:
#            Country                Currency  Currency count
# 0        Australia               Dollar($)              24
# 1           Brazil      Brazilian Real(R$)              60
# 2           Canada               Dollar($)               4
# 3            India      Indian Rupees(Rs.)            8652
# 4        Indonesia  Indonesian Rupiah(IDR)              21
# 5      New Zealand           NewZealand($)              40
# 6      Phillipines        Botswana Pula(P)              22
# 7            Qatar         Qatari Rial(QR)              20
# 8        Singapore               Dollar($)              20
# 9     South Africa                 Rand(R)              60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)              20
# 11          Turkey        Turkish Lira(TL)              34
# 12             UAE      Emirati Diram(AED)              60
# 13  United Kingdom              Pounds(£)              80
# 14   United States               Dollar($)             434

# %%
final_Zomato[['Country','Currency']].groupby(['Country','Currency']).size().reset_index().rename(columns={0:'Currency count'})
# Out:
#            Country                Currency  Currency count
# 0        Australia               Dollar($)              24
# 1           Brazil      Brazilian Real(R$)              60
# 2           Canada               Dollar($)               4
# 3            India      Indian Rupees(Rs.)            8652
# 4        Indonesia  Indonesian Rupiah(IDR)              21
# 5      New Zealand           NewZealand($)              40
# 6      Phillipines        Botswana Pula(P)              22
# 7            Qatar         Qatari Rial(QR)              20
# 8        Singapore               Dollar($)              20
# 9     South Africa                 Rand(R)              60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)              20
# 11          Turkey        Turkish Lira(TL)              34
# 12             UAE      Emirati Diram(AED)              60
# 13  United Kingdom              Pounds(£)              80
# 14   United States               Dollar($)             434

# %%
final_Zomato.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
##  Which countries do have online deliveries option

# %%
final_Zomato[final_Zomato['Has Online delivery']=="Yes"].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %%
final_Zomato[final_Zomato['Has Online delivery']=="Yes"].Country.value_counts().reset_index()
# Out:
#    index  Country
# 0  India     2423
# 1    UAE       28

# %%
## THIS WILL RETURN US WHICH COUNTRY HAS HAS ONLINE DELIVERY.
final_Zomato[['Has Online delivery','Country']].groupby(['Has Online delivery','Country']).size().reset_index()
# Out:
#    Has Online delivery         Country     0
# 0                   No       Australia    24
# 1                   No          Brazil    60
# 2                   No          Canada     4
# 3                   No           India  6229
# 4                   No       Indonesia    21
# 5                   No     New Zealand    40
# 6                   No     Phillipines    22
# 7                   No           Qatar    20
# 8                   No       Singapore    20
# 9                   No    South Africa    60
# 10                  No       Sri Lanka    20
# 11                  No          Turkey    34
# 12                  No             UAE    32
# 13                  No  United Kingdom    80
# 14                  No   United States   434
# 15                 Yes           India  2423
# 16                 Yes             UAE    28

# %%
## THIS WILL RETURN US COLUMNS NAME FROM DATA SET.
final_Zomato.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# ## create a pie chart for top 5 cities distribution

# %%
city_values=final_Zomato.City.value_counts().values

# %%
city_labels=final_Zomato.City.value_counts().index

# %%
plt.pie(city_values,labels=city_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x228c0bbcd30>,
# ...
#  [Text(-0.2501618674207579, 1.0711764747643402, 'New Delhi'),
#   Text(-0.745121915719338, -0.8091930120278745, 'Gurgaon'),
#   Text(-0.023335860702208486, -1.0997524437823665, 'Noida'),
#   Text(0.4451062250173843, -1.0059226851258372, 'Faridabad'),
#   Text(0.5344697170236794, -0.9614271275477035, 'Ghaziabad'),
#   Text(0.5489550432957175, -0.9532304865247423, 'Amritsar'),
#   Text(0.5620711022307091, -0.9455559613461045, 'Guwahati'),
#   Text(0.5750798895062447, -0.9377009761568373, 'Bhubaneshwar'),
#   Text(0.5879789223862543, -0.9296670300863097, 'Ahmedabad'),
#   Text(0.6007657390813725, -0.9214556564186973, 'Lucknow'),
#   Text(0.6131375319471077, -0.9132701500201403, 'Nagpur'),
#   Text(0.625100125752387, -0.9051242084843107, 'Sioux City'),
#   Text(0.6369545100691332, -0.8968215832051494, 'Kochi'),
#   Text(0.6486986328151094, -0.888363711428944, 'Dalton'),
#   Text(0.6603304609951781, -0.8797520572763077, 'Boise'),
# ...

# %%
# PLOTING A PIE FOR TOP 5 SELLING CITY FPR
plt.pie(city_values[:5],labels=city_labels[:5],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x228c0fc4390>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.87%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.07%'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.59%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.16%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.31%')])

# %% [markdown]
# ## Assigment
# Find the top 10 cuisines

# %%
final_Zomato.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
Cuisines_val=final_Zomato.Cuisines.value_counts().values
Cuisines_val
# Out:
# array([936, 511, 354, ...,   1,   1,   1], dtype=int64)

# %%
Cuisines_ind=final_Zomato.Cuisines.value_counts().index
Cuisines_ind
# Out:
# Index(['North Indian', 'North Indian, Chinese', 'Chinese', 'Fast Food',
#        'North Indian, Mughlai', 'Cafe', 'Bakery',
#        'North Indian, Mughlai, Chinese', 'Bakery, Desserts', 'Street Food',
#        ...
#        'North Indian, Mughlai, Continental, Chinese',
#        'Chinese, Seafood, Cantonese, Dim Sum',
#        'Asian, Latin American, Vegetarian', 'Kebab, Turkish Pizza, Dí_ner',
#        'Continental, Middle Eastern, Asian', 'Continental, American, Cafe',
#        'North Indian, Lebanese, European, Mexican',
#        'Fast Food, North Indian, South Indian, Chinese, Bakery',
#        'Continental, Finger Food, Chinese, North Indian',
#        'Healthy Food, Continental, North Indian, Salad'],
#       dtype='object', length=1825)

# %%
plt.pie(Cuisines_val[:10],labels=Cuisines_ind[:10],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x228c0e427f0>,
# ...
#  [Text(0.7383739846958008, 0.8153550507137645, 'North Indian'),
#   Text(-0.5794679314239953, 0.9349956772366362, 'North Indian, Chinese'),
#   Text(-1.067309479615702, 0.26617752482593154, 'Chinese'),
#   Text(-1.0185984499802057, -0.4152796620326146, 'Fast Food'),
#   Text(-0.5935788454809928, -0.9261015895664211, 'North Indian, Mughlai'),
#   Text(-0.005887079599915552, -1.0999842463843672, 'Cafe'),
#   Text(0.4842062514572988, -0.9876964645323336, 'Bakery'),
#   Text(0.808736477166136, -0.7456174022251013, 'North Indian, Mughlai, Chinese'),
#   Text(1.0055375294202338, -0.44597564611473206, 'Bakery, Desserts'),
#   Text(1.090298995560443, -0.14576728123927227, 'Street Food')],
#  [Text(0.4027494461977095, 0.4447391185711442, '26.58%'),
#   Text(-0.316073417140361, 0.5099976421290743, '14.51%'),
#   Text(-0.5821688070631101, 0.14518774081414446, '10.05%'),
#   Text(-0.5555991545346576, -0.22651617929051704, '10.05%'),
# ...

# %%
plt.pie(Cuisines_val[:10],labels=Cuisines_ind[:10],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x228c0e427f0>,
# ...
#  [Text(0.7383739846958008, 0.8153550507137645, 'North Indian'),
#   Text(-0.5794679314239953, 0.9349956772366362, 'North Indian, Chinese'),
#   Text(-1.067309479615702, 0.26617752482593154, 'Chinese'),
#   Text(-1.0185984499802057, -0.4152796620326146, 'Fast Food'),
#   Text(-0.5935788454809928, -0.9261015895664211, 'North Indian, Mughlai'),
#   Text(-0.005887079599915552, -1.0999842463843672, 'Cafe'),
#   Text(0.4842062514572988, -0.9876964645323336, 'Bakery'),
#   Text(0.808736477166136, -0.7456174022251013, 'North Indian, Mughlai, Chinese'),
#   Text(1.0055375294202338, -0.44597564611473206, 'Bakery, Desserts'),
#   Text(1.090298995560443, -0.14576728123927227, 'Street Food')],
#  [Text(0.4027494461977095, 0.4447391185711442, '26.58%'),
#   Text(-0.316073417140361, 0.5099976421290743, '14.51%'),
#   Text(-0.5821688070631101, 0.14518774081414446, '10.05%'),
#   Text(-0.5555991545346576, -0.22651617929051704, '10.05%'),
# ...

# %%
sns.regplot(x='Aggregate rating',y='Price range', data=final_Zomato)
